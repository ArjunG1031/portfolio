# %% [markdown]
# ---
# layout: post
# codemirror: true
# microblog: true
# title: HW Summation
# description: Full HW Summation
# permalink: /js/hwsummation
# author: Arjun
# ---

# %% [markdown]
# ## Homeworks
#
# - [Strings Homework]({{ site.baseurl }}/js/stringshw)
# - [Classes]({{ site.baseurl }}/js/classes)
# - [Booleans]({{ site.baseurl }}/js/booleans)
# - [Math]({{ site.baseurl }}/js/math)
# - [JSON]({{ site.baseurl }}/js/json)
# - [Data Abstraction]({{ site.baseurl }}/js/dataabstraction)
# - [Nested Conditionals]({{ site.baseurl }}/js/nested-conditionals)
# - [Iterations]({{ site.baseurl }}/js/iterationshw)
# - [Variables]({{ site.baseurl }}/js/variables)
